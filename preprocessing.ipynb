# %% [markdown]
# ## Anxiety, stress and depression on University Students
# We found a [research](https://figshare.com/articles/dataset/MHP_Anxiety_Stress_Depression_Dataset_of_University_Students/25771164) about the feelings of different students.

# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %%
raw_data = pd.read_csv('data/Raw Dataset.csv')
processed = pd.read_csv('data/Processed.csv')
depression = pd.read_csv('data/Depression.csv')
anxiety = pd.read_csv('data/Anxiety.csv')
stress = pd.read_csv('data/Stress.csv')

# %%
raw_data
# Out:
#      1. Age 2. Gender                                      3. University  \
# 0     18-22    Female           Independent University, Bangladesh (IUB)
# 1     18-22      Male           Independent University, Bangladesh (IUB)
# 2     18-22      Male  American International University Bangladesh (...
# 3     18-22      Male  American International University Bangladesh (...
# 4     18-22      Male                       North South University (NSU)
# ...     ...       ...                                                ...
# 2023  18-22      Male                              Dhaka University (DU)
# 2024  18-22    Female           Bangladesh Agricultural University (BAU)
# 2025  18-22      Male  American International University Bangladesh (...
# 2026  23-26    Female                              Dhaka University (DU)
# 2027  18-22      Male           Independent University, Bangladesh (IUB)
#
#                                      4. Department           5. Academic Year  \
# 0     Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
# 1     Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 2     Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 3     Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 4     Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
# ...                                            ...                        ...
# 2023                                         Other  Second Year or Equivalent
# 2024  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 2025  Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
# 2026                                         Other   Third Year or Equivalent
# 2027         Business and Entrepreneurship Studies  Second Year or Equivalent
#
#      6. Current CGPA  \
# 0        2.50 - 2.99
# 1        3.00 - 3.39
# 2        3.00 - 3.39
# 3        3.00 - 3.39
# 4        2.50 - 2.99
# ...              ...
# 2023     3.00 - 3.39
# 2024     3.00 - 3.39
# 2025     2.50 - 2.99
# 2026     3.40 - 3.79
# 2027     2.50 - 2.99
#
#      7. Did you receive a waiver or scholarship at your university?  \
# 0                                                    No
# 1                                                    No
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 2023                                                 No
# 2024                                                 No
# 2025                                                 No
# 2026                                                 No
# 2027                                                 No
#
#      1. In a semester, how often have you felt upset due to something that happened in your academic affairs?   \
# 0                                      3 - Fairly Often
# 1                                      3 - Fairly Often
# 2                                             0 - Never
# 3                                      3 - Fairly Often
# 4                                        4 - Very Often
# ...                                                 ...
# 2023                                     4 - Very Often
# 2024                                     4 - Very Often
# 2025                                     4 - Very Often
# 2026                                     4 - Very Often
# 2027                                      2 - Sometimes
#
#      2. In a semester, how often you felt as if you were unable to control important things in your academic affairs?  \
# 0                                        4 - Very Often
# 1                                      3 - Fairly Often
# 2                                             0 - Never
# 3                                      1 - Almost Never
# 4                                        4 - Very Often
# ...                                                 ...
# 2023                                     4 - Very Often
# 2024                                     4 - Very Often
# 2025                                      2 - Sometimes
# 2026                                     4 - Very Often
# 2027                                      2 - Sometimes
#
#      3. In a semester, how often you felt nervous and stressed because of academic pressure?   \
# 0                                      3 - Fairly Often
# 1                                        4 - Very Often
# 2                                             0 - Never
# 3                                         2 - Sometimes
# 4                                        4 - Very Often
# ...                                                 ...
# 2023                                     4 - Very Often
# 2024                                     4 - Very Often
# 2025                                   1 - Almost Never
# 2026                                     4 - Very Often
# 2027                                   3 - Fairly Often
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 2023  ...
# 2024  ...
# 2025  ...
# 2026  ...
# 2027  ...
#
#      7. In a semester, how often have you felt afraid, as if something awful might happen?  \
# 0                           2 - More than half the days
# 1                           2 - More than half the days
# 2                                        0 - Not at all
# 3                           2 - More than half the days
# 4                                  3 - Nearly every day
# ...                                                 ...
# 2023                               3 - Nearly every day
# 2024                               3 - Nearly every day
# 2025                                   1 - Several days
# 2026                               3 - Nearly every day
# 2027                        2 - More than half the days
#
#      1. In a semester, how often have you had little interest or pleasure in doing things?  \
# 0                           2 - More than half the days
# 1                                  3 - Nearly every day
# 2                                        0 - Not at all
# 3                           2 - More than half the days
# 4                                      1 - Several days
# ...                                                 ...
# 2023                                   1 - Several days
# 2024                                     0 - Not at all
# 2025                                   1 - Several days
# 2026                               3 - Nearly every day
# 2027                                   1 - Several days
#
#      2. In a semester, how often have you been feeling down, depressed or hopeless?  \
# 0                           2 - More than half the days
# 1                           2 - More than half the days
# 2                                        0 - Not at all
# 3                                      1 - Several days
# 4                                  3 - Nearly every day
# ...                                                 ...
# 2023                                   1 - Several days
# 2024                               3 - Nearly every day
# 2025                                   1 - Several days
# 2026                               3 - Nearly every day
# 2027                        2 - More than half the days
#
#      3. In a semester, how often have you had trouble falling or staying asleep, or sleeping too much?   \
# 0                                  3 - Nearly every day
# 1                           2 - More than half the days
# 2                                        0 - Not at all
# 3                           2 - More than half the days
# 4                                  3 - Nearly every day
# ...                                                 ...
# 2023                               3 - Nearly every day
# 2024                               3 - Nearly every day
# 2025                        2 - More than half the days
# 2026                               3 - Nearly every day
# 2027                                   1 - Several days
#
#      4. In a semester, how often have you been feeling tired or having little energy?   \
# 0                           2 - More than half the days
# 1                           2 - More than half the days
# 2                                        0 - Not at all
# 3                                      1 - Several days
# 4                                  3 - Nearly every day
# ...                                                 ...
# 2023                               3 - Nearly every day
# 2024                               3 - Nearly every day
# 2025                                   1 - Several days
# 2026                               3 - Nearly every day
# 2027                        2 - More than half the days
#
#      5. In a semester, how often have you had poor appetite or overeating?   \
# 0                           2 - More than half the days
# 1                           2 - More than half the days
# 2                                        0 - Not at all
# 3                           2 - More than half the days
# 4                                      1 - Several days
# ...                                                 ...
# 2023                                     0 - Not at all
# 2024                        2 - More than half the days
# 2025                        2 - More than half the days
# 2026                               3 - Nearly every day
# 2027                        2 - More than half the days
#
#      6. In a semester, how often have you been feeling bad about yourself - or that you are a failure or have let yourself or your family down?   \
# 0                           2 - More than half the days
# 1                           2 - More than half the days
# 2                                        0 - Not at all
# 3                                      1 - Several days
# 4                                  3 - Nearly every day
# ...                                                 ...
# 2023                               3 - Nearly every day
# 2024                               3 - Nearly every day
# 2025                        2 - More than half the days
# 2026                               3 - Nearly every day
# 2027                                   1 - Several days
#
#      7. In a semester, how often have you been having trouble concentrating on things, such as reading the books or watching television?   \
# 0                           2 - More than half the days
# 1                           2 - More than half the days
# 2                                        0 - Not at all
# 3                           2 - More than half the days
# 4                                        0 - Not at all
# ...                                                 ...
# 2023                        2 - More than half the days
# 2024                                   1 - Several days
# 2025                        2 - More than half the days
# 2026                               3 - Nearly every day
# 2027                                   1 - Several days
#
#      8. In a semester, how often have you moved or spoke too slowly for other people to notice? Or you've been moving a lot more than usual because you've been restless?   \
# 0                                  3 - Nearly every day
# 1                           2 - More than half the days
# 2                                        0 - Not at all
# 3                           2 - More than half the days
# 4                                  3 - Nearly every day
# ...                                                 ...
# 2023                        2 - More than half the days
# 2024                                   1 - Several days
# 2025                        2 - More than half the days
# 2026                                     0 - Not at all
# 2027                        2 - More than half the days
#
#      9. In a semester, how often have you had thoughts that you would be better off dead, or of hurting yourself?
# 0                           2 - More than half the days
# 1                           2 - More than half the days
# 2                                        0 - Not at all
# 3                                      1 - Several days
# 4                                  3 - Nearly every day
# ...                                                 ...
# 2023                               3 - Nearly every day
# 2024                               3 - Nearly every day
# 2025                        2 - More than half the days
# 2026                                     0 - Not at all
# 2027                        2 - More than half the days
#
# [2028 rows x 33 columns]

# %% [markdown]
# ### Pre-processing

# %%
raw_data.rename(lambda x: x.split(". ")[1], axis=1, inplace=True)

# %% [markdown]
# Now we get the numeric value for each question and sum it up depending on its category (stress, anxiety and depression). We decided to put different weights to different questions because they are not all equally important.
#
# Then we drop the columns representing this questions (and the column asking if the student received a scholarship because everyone said no).

# %%
question_weights = [
    [0.1, 0.2, 0.15, 0.2, 0.05, 0.05, 0.05, 0.05, 0.1, 0.2],
    [0.2, 0.2, 0.15, 0.1, 0.15, 0.1, 0.1],
    [0.15, 0.2, 0.1, 0.1, 0.08, 0.12, 0.1, 0.05, 0.2],
]

# %%
questions_values = raw_data.iloc[:, 7:].map(lambda x: int(x[0]))

raw_data["Stress value"] = (questions_values.iloc[:, :10] * question_weights[0]).sum(axis=1)
raw_data["Anxiety value"] = (questions_values.iloc[:, 10:17] * question_weights[1]).sum(axis=1)
raw_data["Depression value"] = (questions_values.iloc[:, 17:] * question_weights[2]).sum(axis=1)

raw_data["Stress value"] = (raw_data["Stress value"] - raw_data["Stress value"].min()) / (raw_data["Stress value"].max() - raw_data["Stress value"].min())
raw_data["Anxiety value"] = (raw_data["Anxiety value"] - raw_data["Anxiety value"].min()) / (raw_data["Anxiety value"].max() - raw_data["Anxiety value"].min())
raw_data["Depression value"] = (raw_data["Depression value"] - raw_data["Depression value"].min()) / (raw_data["Depression value"].max() - raw_data["Depression value"].min())


raw_data = raw_data.drop(columns=raw_data.columns[6:33])
raw_data
# Out:
#         Age  Gender                                         University  \
# 0     18-22  Female           Independent University, Bangladesh (IUB)
# 1     18-22    Male           Independent University, Bangladesh (IUB)
# 2     18-22    Male  American International University Bangladesh (...
# 3     18-22    Male  American International University Bangladesh (...
# 4     18-22    Male                       North South University (NSU)
# ...     ...     ...                                                ...
# 2023  18-22    Male                              Dhaka University (DU)
# 2024  18-22  Female           Bangladesh Agricultural University (BAU)
# 2025  18-22    Male  American International University Bangladesh (...
# 2026  23-26  Female                              Dhaka University (DU)
# 2027  18-22    Male           Independent University, Bangladesh (IUB)
#
#                                         Department              Academic Year  \
# 0     Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
# 1     Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 2     Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 3     Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 4     Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
# ...                                            ...                        ...
# 2023                                         Other  Second Year or Equivalent
# 2024  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 2025  Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
# 2026                                         Other   Third Year or Equivalent
# 2027         Business and Entrepreneurship Studies  Second Year or Equivalent
#
#      Current CGPA  Stress value  Anxiety value  Depression value
# 0     2.50 - 2.99      0.760870       0.716667          0.712121
# 1     3.00 - 3.39      0.684783       0.550000          0.712121
# 2     3.00 - 3.39      0.010870       0.000000          0.000000
# 3     3.00 - 3.39      0.489130       0.483333          0.478788
# 4     2.50 - 2.99      0.804348       0.633333          0.769697
# ...           ...           ...            ...               ...
# 2023  3.00 - 3.39      0.793478       1.000000          0.669697
# 2024  3.00 - 3.39      0.826087       0.800000          0.748485
# 2025  2.50 - 2.99      0.554348       0.633333          0.530303
# 2026  3.40 - 3.79      0.847826       1.000000          0.772727
# 2027  2.50 - 2.99      0.641304       0.633333          0.524242
#
# [2028 rows x 9 columns]

# %% [markdown]
# We change the Academic Year column to make it easier to understand. We use numbers for the years instead of text.
#
# Finally, we drop the rows with missing values and years considered "others" since they are not relevant for our analysis and ca be considered outliers.

# %%
years = {
    "First Year or Equivalent": 1,
    "Second Year or Equivalent": 2,
    "Third Year or Equivalent": 3,
    "Fourth Year or Equivalent": 4,
    "Fifth Year or Equivalent": 5
}

raw_data["Academic Year"] = raw_data["Academic Year"].apply(lambda x: int(years.get(x)) if x in years.keys() else 0)
# raw_data = raw_data[raw_data["Academic Year"] != 0]
raw_data["Academic Year"] = raw_data["Academic Year"].astype("Int64")
raw_data.rename(columns={"Academic Year": "Year"}, inplace=True)

# %%
departements = raw_data["Department"].unique()
raw_data["Department"] = raw_data["Department"].apply(lambda x: x.split("/")[0])

# %% [markdown]
# Checking correlation between stress, anxiety and depression. We consider more than 0.90 as a high correlation between attributes. In this case there is no correlation higher than 0.77.

# %%
raw_data[["Year", "Stress value", "Anxiety value", "Depression value"]].corr()
# Out:
#                       Year  Stress value  Anxiety value  Depression value
# Year              1.000000      0.051450       0.070788          0.052358
# Stress value      0.051450      1.000000       0.674662          0.590094
# Anxiety value     0.070788      0.674662       1.000000          0.754770
# Depression value  0.052358      0.590094       0.754770          1.000000

# %%
raw_data
# Out:
#         Age  Gender                                         University  \
# 0     18-22  Female           Independent University, Bangladesh (IUB)
# 1     18-22    Male           Independent University, Bangladesh (IUB)
# 2     18-22    Male  American International University Bangladesh (...
# 3     18-22    Male  American International University Bangladesh (...
# 4     18-22    Male                       North South University (NSU)
# ...     ...     ...                                                ...
# 2023  18-22    Male                              Dhaka University (DU)
# 2024  18-22  Female           Bangladesh Agricultural University (BAU)
# 2025  18-22    Male  American International University Bangladesh (...
# 2026  23-26  Female                              Dhaka University (DU)
# 2027  18-22    Male           Independent University, Bangladesh (IUB)
#
#                                  Department  Year Current CGPA  Stress value  \
# 0                         Engineering - CS      2  2.50 - 2.99      0.760870
# 1                         Engineering - CS      3  3.00 - 3.39      0.684783
# 2                         Engineering - CS      3  3.00 - 3.39      0.010870
# 3                         Engineering - CS      3  3.00 - 3.39      0.489130
# 4                         Engineering - CS      2  2.50 - 2.99      0.804348
# ...                                     ...   ...          ...           ...
# 2023                                  Other     2  3.00 - 3.39      0.793478
# 2024                      Engineering - CS      3  3.00 - 3.39      0.826087
# 2025                      Engineering - CS      2  2.50 - 2.99      0.554348
# 2026                                  Other     3  3.40 - 3.79      0.847826
# 2027  Business and Entrepreneurship Studies     2  2.50 - 2.99      0.641304
#
#       Anxiety value  Depression value
# 0          0.716667          0.712121
# 1          0.550000          0.712121
# 2          0.000000          0.000000
# 3          0.483333          0.478788
# 4          0.633333          0.769697
# ...             ...               ...
# 2023       1.000000          0.669697
# 2024       0.800000          0.748485
# 2025       0.633333          0.530303
# 2026       1.000000          0.772727
# 2027       0.633333          0.524242
#
# [2028 rows x 9 columns]

# %%
raw_data["University"].value_counts()
# Out:
# University
# Independent University, Bangladesh (IUB)                      532
# American International University Bangladesh (AIUB)           504
# Islamic University of Technology (IUT)                        269
# Dhaka University (DU)                                         202
# Dhaka University of Engineering and Technology (DUET)         162
# North South University (NSU)                                   87
# Bangladesh University of Engineering and Technology (BUET)     63
# Patuakhali Science and Technology University                   50
# East West University (EWU)                                     42
# Rajshahi University of Engineering and Technology (RUET)       31
# Rajshahi University (RU)                                       23
# BRAC University                                                20
# United International University (UIU)                          18
# Bangladesh Agricultural University (BAU)                       14
# Daffodil University                                            11
# Name: count, dtype: int64

# %% [markdown]
# ## Save the data

# %%
raw_data.to_csv("Preprocessed.csv", index=False)
# print(processed[['Depression Value', 'Depression Label']].drop_duplicates())
# print(processed[['Anxiety Value', 'Anxiety Label']].drop_duplicates())
print(processed[['Stress Value', 'Stress Label']].drop_duplicates())
# Out:
#       Stress Value           Stress Label
# 0               29  High Perceived Stress
# 1               24        Moderate Stress
# 2               15        Moderate Stress
# 3               17        Moderate Stress
# 4               32  High Perceived Stress
# 5               16        Moderate Stress
# 6               18        Moderate Stress
# 7                8             Low Stress
# 10              23        Moderate Stress
# 12              20        Moderate Stress
# 16              21        Moderate Stress
# 18              36  High Perceived Stress
# 20              26        Moderate Stress
# 22              22        Moderate Stress
# 23              34  High Perceived Stress
# 27              30  High Perceived Stress
# 28              27  High Perceived Stress
# 44              25        Moderate Stress
# 45              38  High Perceived Stress
# 54              28  High Perceived Stress
# 60              37  High Perceived Stress
# 67              19        Moderate Stress
# 71              14        Moderate Stress
# 76              40  High Perceived Stress
# 79              39  High Perceived Stress
# 83              31  High Perceived Stress
# 92              33  High Perceived Stress
# 114             35  High Perceived Stress
# 160             11             Low Stress
# 205             10             Low Stress
# 255             12             Low Stress
# 292             13             Low Stress
# 336              7             Low Stress
# 520              9             Low Stress
# 777              0             Low Stress
# 1152             3             Low Stress
# 1237             5             Low Stress
# 1647             6             Low Stress
